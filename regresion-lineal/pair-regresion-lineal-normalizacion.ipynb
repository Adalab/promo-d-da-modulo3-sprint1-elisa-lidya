# %% [markdown]
# ## Pair Programming Normalización

# %% [markdown]
# En este ejercicio de pair programming seguiréis usando el dataset que seleccionasteis.
#
# En vuestro dataset habréis identificado unas variables predictoras y una variable respuesta. Los objetivos del pair programming de hoy son:
# - Sobre la variable respuesta, en pair programmings anterior identificastéis si seguía una distribución normal o no. En caso de que no siguiera una distribución normal, normalizarla. Podéis usar el método que prefiráis o el que mejor se ajuste

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Gráficos
# ------------------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Transformación de los datos
# ------------------------------------------------------------------------------
from scipy import stats
import math 
from sklearn.preprocessing import MinMaxScaler

# Para la gestión de los warning
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# Para poder ver todas las columnas del dataframe
# ------------------------------------------------------------------------------
pd.options.display.max_columns = None 

import os

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/User/Desktop/ADALAB/MODULO3'

# %%
os.chdir('/mnt/c/Users/User/Desktop/ADALAB/MODULO3/promo-d-da-modulo3-sprint1-elisa-lidya/regresion-lineal')

# %%
df_socio = pd.read_csv('../datos/esperanza_de_vida.csv', index_col=0)
df_socio.head(2)
# Out:
#      country        Region  Population in millions (2017)  \
# 0  Argentina  SouthAmerica                         44.271
# 1  Australia       Oceania                         24.451
#
#    Population density (per km2, 2017)  \
# 0                                16.2
# 1                                 3.2
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                      91.749                       14564.5
# 1                                      85.904                       51352.2
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                                   4.8              73.30
# 1                                   9.4              74.25
#
#    Health: Physicians (per 1000 pop.) Quantity of Physicians (per 1000 pop.)  \
# 0                                 3.8                                 Muchos
# 1                                 3.4                                 Medios
#
#    Quality Of Life Index  Purchasing Power Index  Safety Index  \
# 0                 139.59                   58.40         37.37
# 1                 176.54                  101.94         57.58
#
#    Pop. using improved drinking water: urban(%)  \
# 0                                          96.2
# 1                                         100.0
#
#    Pop. using improved drinking water: rural (%)  Pollution index  \
# 0                                           98.3            53.33
# 1                                          100.0            24.58
#
#    Life expectancy at birth, total (years)
# 0                                   76.372
# 1                                   82.500

# %%
sns.displot(x='Life expectancy at birth, total (years)', data=df_socio, kde = True, color = "purple");

# %%
sns.histplot(x=df_socio["Life expectancy at birth, total (years)"], bins = 40);

# %%
#sacamos la normalización con el modelo de MinMaxScaler

numericas = df_socio.select_dtypes(include=np.number)
numericas.head()
# Out:
#    Population in millions (2017)  Population density (per km2, 2017)  \
# 0                         44.271                                16.2
# 1                         24.451                                 3.2
# 2                          8.736                               106.0
# 3                          9.468                                46.7
# 4                         11.429                               377.5
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                      91.749                       14564.5
# 1                                      85.904                       51352.2
# 2                                      58.094                       44117.7
# 3                                      78.134                        5750.8
# 4                                      97.961                       40277.8
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                                   4.8              73.30
# 1                                   9.4              74.25
# 2                                  11.2              80.91
# 3                                   5.7              53.76
# 4                                  10.6              78.92
#
#    Health: Physicians (per 1000 pop.)  Quality Of Life Index  \
# 0                                 3.8                 139.59
# 1                                 3.4                 176.54
# 2                                 5.2                 190.37
# 3                                 4.1                 119.23
# 4                                 3.0                 160.52
#
#    Purchasing Power Index  Safety Index  \
# 0                   58.40         37.37
# 1                  101.94         57.58
# 2                   95.66         80.75
# 3                   36.43         77.74
# 4                   91.02         55.49
#
#    Pop. using improved drinking water: urban(%)  \
# 0                                          96.2
# 1                                         100.0
# 2                                         100.0
# 3                                          94.1
# 4                                          99.5
#
#    Pop. using improved drinking water: rural (%)  Pollution index  \
# 0                                           98.3            53.33
# 1                                          100.0            24.58
# 2                                          100.0            21.90
# 3                                           95.2            39.64
# 4                                           99.4            48.92
#
#    Life expectancy at birth, total (years)
# 0                                76.372000
# 1                                82.500000
# 2                                81.643902
# 3                                74.129268
# 4                                81.492683

# %%
df_socio_copy = df_socio.copy()

# %%
minmax = MinMaxScaler()
minmax.fit(df_socio_copy[['Life expectancy at birth, total (years)']])
vr_norm = minmax.transform(df_socio_copy[['Life expectancy at birth, total (years)']])

# %%
df_norm = pd.DataFrame(vr_norm, columns=['Life expectancy at birth, total (sk-normalized)'])
df_norm.head()
# Out:
#    Life expectancy at birth, total (sk-normalized)
# 0                                         0.607024
# 1                                         0.896867
# 2                                         0.856375
# 3                                         0.500947
# 4                                         0.849223

# %%
df_socio_copy['Life expectancy at birth, total (sk-normalized)'] = df_norm

# %%
df_socio_copy.head()
# Out:
#      country         Region  Population in millions (2017)  \
# 0  Argentina   SouthAmerica                         44.271
# 1  Australia        Oceania                         24.451
# 2    Austria  WesternEurope                          8.736
# 3    Belarus  EasternEurope                          9.468
# 4    Belgium  WesternEurope                         11.429
#
#    Population density (per km2, 2017)  \
# 0                                16.2
# 1                                 3.2
# 2                               106.0
# 3                                46.7
# 4                               377.5
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                      91.749                       14564.5
# 1                                      85.904                       51352.2
# 2                                      58.094                       44117.7
# 3                                      78.134                        5750.8
# 4                                      97.961                       40277.8
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                                   4.8              73.30
# 1                                   9.4              74.25
# 2                                  11.2              80.91
# 3                                   5.7              53.76
# 4                                  10.6              78.92
#
#    Health: Physicians (per 1000 pop.) Quantity of Physicians (per 1000 pop.)  \
# 0                                 3.8                                 Muchos
# 1                                 3.4                                 Medios
# 2                                 5.2                                 Muchos
# 3                                 4.1                                 Muchos
# 4                                 3.0                                 Medios
#
#    Quality Of Life Index  Purchasing Power Index  Safety Index  \
# 0                 139.59                   58.40         37.37
# 1                 176.54                  101.94         57.58
# 2                 190.37                   95.66         80.75
# 3                 119.23                   36.43         77.74
# 4                 160.52                   91.02         55.49
#
#    Pop. using improved drinking water: urban(%)  \
# 0                                          96.2
# 1                                         100.0
# 2                                         100.0
# 3                                          94.1
# 4                                          99.5
#
#    Pop. using improved drinking water: rural (%)  Pollution index  \
# 0                                           98.3            53.33
# 1                                          100.0            24.58
# 2                                          100.0            21.90
# 3                                           95.2            39.64
# 4                                           99.4            48.92
#
#    Life expectancy at birth, total (years)  \
# 0                                76.372000
# 1                                82.500000
# 2                                81.643902
# 3                                74.129268
# 4                                81.492683
#
#    Life expectancy at birth, total (sk-normalized)
# 0                                         0.607024
# 1                                         0.896867
# 2                                         0.856375
# 3                                         0.500947
# 4                                         0.849223

# %%
fig, axes = plt.subplots(1, 2, figsize = (15,5))

axes[0].set_title('Life expectancy at birth, total (years)')
axes[1].set_title('Life expectancy at birth, total (sk-normalized)')

sns.distplot(df_socio_copy['Life expectancy at birth, total (years)'] ,ax = axes[0])
sns.distplot(df_socio_copy['Life expectancy at birth, total (sk-normalized)'], ax = axes[1]);

# %%
stats.shapiro(df_socio['Life expectancy at birth, total (sk-normalized)'])
# Out:
# ShapiroResult(statistic=0.9383592009544373, pvalue=0.002661846810951829)

# %% [markdown]
# `Dado que el MinMaxScaler no nos ha dado resultado, procedemos a realizar el Boxcox.`

# %%
df_socio['Life expectancy at birth, total (bc-normalized)'], lambda_bc = stats.boxcox(df_socio['Life expectancy at birth, total (years)'])

# %%
df_socio.head()
# Out:
#      country         Region  Population in millions (2017)  \
# 0  Argentina   SouthAmerica                         44.271
# 1  Australia        Oceania                         24.451
# 2    Austria  WesternEurope                          8.736
# 3    Belarus  EasternEurope                          9.468
# 4    Belgium  WesternEurope                         11.429
#
#    Population density (per km2, 2017)  \
# 0                                16.2
# 1                                 3.2
# 2                               106.0
# 3                                46.7
# 4                               377.5
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                      91.749                       14564.5
# 1                                      85.904                       51352.2
# 2                                      58.094                       44117.7
# 3                                      78.134                        5750.8
# 4                                      97.961                       40277.8
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                                   4.8              73.30
# 1                                   9.4              74.25
# 2                                  11.2              80.91
# 3                                   5.7              53.76
# 4                                  10.6              78.92
#
#    Health: Physicians (per 1000 pop.) Quantity of Physicians (per 1000 pop.)  \
# 0                                 3.8                                 Muchos
# 1                                 3.4                                 Medios
# 2                                 5.2                                 Muchos
# 3                                 4.1                                 Muchos
# 4                                 3.0                                 Medios
#
#    Quality Of Life Index  Purchasing Power Index  Safety Index  \
# 0                 139.59                   58.40         37.37
# 1                 176.54                  101.94         57.58
# 2                 190.37                   95.66         80.75
# 3                 119.23                   36.43         77.74
# 4                 160.52                   91.02         55.49
#
#    Pop. using improved drinking water: urban(%)  \
# 0                                          96.2
# 1                                         100.0
# 2                                         100.0
# 3                                          94.1
# 4                                          99.5
#
#    Pop. using improved drinking water: rural (%)  Pollution index  \
# 0                                           98.3            53.33
# 1                                          100.0            24.58
# 2                                          100.0            21.90
# 3                                           95.2            39.64
# 4                                           99.4            48.92
#
#    Life expectancy at birth, total (years)  \
# 0                                76.372000
# 1                                82.500000
# 2                                81.643902
# 3                                74.129268
# 4                                81.492683
#
#    Life expectancy at birth, total (sk-normalized)  \
# 0                                         0.607024
# 1                                         0.896867
# 2                                         0.856375
# 3                                         0.500947
# 4                                         0.849223
#
#    Life expectancy at birth, total (bc-normalized)
# 0                                     1.596496e+11
# 1                                     2.611737e+11
# 2                                     2.443653e+11
# 3                                     1.320137e+11
# 4                                     2.414933e+11

# %%
fig, axes = plt.subplots(1, 2, figsize = (15,5))

axes[0].set_title('Life expectancy at birth, total (years)')
axes[1].set_title('Life expectancy at birth, total (bc-normalized)')

sns.distplot(df_socio['Life expectancy at birth, total (years)'] ,ax = axes[0])
sns.distplot(df_socio['Life expectancy at birth, total (bc-normalized)'], ax = axes[1]);

# %%
stats.shapiro(df_socio['Life expectancy at birth, total (bc-normalized)'])
# Out:
# ShapiroResult(statistic=0.965214192867279, pvalue=0.06095479056239128)

# %%
df_socio.drop()

# %% [markdown]
# - Guardar en un csv el nuevo dataframe que habéis creado para seguir usándolo en los siguientes pair programmings

# %%
df_socio_copy.to_csv('../datos/esperanza_de_vida_norm.csv')
