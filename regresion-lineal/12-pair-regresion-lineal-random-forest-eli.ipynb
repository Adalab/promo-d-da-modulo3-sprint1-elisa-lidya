# %% [markdown]
# # **Ejercicios de pair programming Módulo 3 Sprint 1**
# ## **Regresión lineal: Lección 12**
# ### **Random Forest**
#
# ---

# %%
# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Modelado y evaluación
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV

# Barra de progreso de un proceso
# ------------------------------------------------------------------------------
from tqdm import tqdm

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('once')

# %% [markdown]
# En el pair programming de hoy debéis usar el csv que guardastéis cuando hicistéis el pairprgramming de codificicación (este csv debería tener las variables estadandarizas).

# %%
df_socio = pd.read_csv('../datos/esperanza_vida_encoding_eli.csv', index_col=0)
df_socio.head(2)
# Out:
#            region  population_in_millions  population_density  \
# country
# Argentina       2                  44.271                16.2
# Australia       3                  24.451                 3.2
#
#            urban_population_y  gdp_per_capita  health_total_expenditure  \
# country
# Argentina              91.749         14564.5                       4.8
# Australia              85.904         51352.2                       9.4
#
#            health_care_index  health_physicians  quantity_of_physicians  \
# country
# Argentina              73.30                3.8                     3.0
# Australia              74.25                3.4                     2.5
#
#            quality_of_life_index  purchasing_power_index  safety_index  \
# country
# Argentina                 139.59                   58.40         37.37
# Australia                 176.54                  101.94         57.58
#
#            pop_using_improved_drinking_water_urban  \
# country
# Argentina                                     96.2
# Australia                                    100.0
#
#            pop_using_improved_drinking_water_rural  pollution_index  \
# country
# Argentina                                     98.3            53.33
# Australia                                    100.0            24.58
#
#            life_expectancy_at_birth_total_bc
# country
# Argentina                       1.596496e+11
# Australia                       2.611737e+11
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.

# %% [markdown]
# En pairprogramming anteriores ajustastéis vuestro datos a una regresión lineal y a un Decision Tree. El objetivo de hoy es:
#  - Ajustar el modelo a un Random Forest

# %%
X = df_socio.drop('life_expectancy_at_birth_total_bc', axis=1)
y = df_socio['life_expectancy_at_birth_total_bc']
# Out:
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f905ee62860>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 63)

bosque = RandomForestRegressor(max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=10, random_state= 137)

bosque.fit(x_train, y_train)

y_pred_test = bosque.predict(x_test)
y_pred_train = bosque.predict(x_train)

# %% [markdown]
#  - Extraer las métricas

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    
    
    resultados = {'MAE': [mean_absolute_error(y_test, y_test_pred), mean_absolute_error(y_train, y_train_pred)],
                'MSE': [mean_squared_error(y_test, y_test_pred), mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(mean_squared_error(y_test, y_test_pred)), np.sqrt(mean_squared_error(y_train, y_train_pred))],
                'R2':  [r2_score(y_test, y_test_pred), r2_score(y_train, y_train_pred)],
                "set": ["test", "train"]}
    
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
resultados1 = metricas(y_test, y_train, y_pred_test, y_pred_train, 'Random Forest Eli')

# %%
resultados1
# Out:
#             MAE           MSE          RMSE        R2    set  \
# 0  2.862054e+10  1.250301e+21  3.535960e+10  0.613592   test
# 1  1.958149e+10  6.711274e+20  2.590613e+10  0.820448  train
#
#               modelo
# 0  Random Forest Eli
# 1  Random Forest Eli

# %% [markdown]
#  - Debatid entre vosotras que modelo es mejor y por qué (basándose en las métricas)

# %%
resultados =  pd.read_csv("../datos/esperanza_vida_metricas_eli.csv", index_col = 0)

# %%
resultados = pd.concat([resultados, resultados1], axis = 0)
resultados
# Out:
#             MAE           MSE          RMSE        R2    set  \
# 0  2.883072e+10  1.313844e+21  3.624699e+10  0.474558   test
# 1  1.836712e+10  5.124966e+20  2.263839e+10  0.873105  train
# 0  4.122809e+10  3.118462e+21  5.584319e+10  0.036232   test
# 1  0.000000e+00  0.000000e+00  0.000000e+00  1.000000  train
# 0  4.205476e+10  2.298900e+21  4.794685e+10  0.289520   test
# 1  1.706515e+10  5.132659e+20  2.265537e+10  0.862682  train
# 0  4.122809e+10  3.118462e+21  5.584319e+10  0.036232   test
# 1  0.000000e+00  0.000000e+00  0.000000e+00  1.000000  train
# 0  3.551531e+10  2.156879e+21  4.644221e+10  0.333412   test
# 1  2.008774e+10  6.703296e+20  2.589072e+10  0.820661  train
# 0  2.862054e+10  1.250301e+21  3.535960e+10  0.613592   test
# 1  1.958149e+10  6.711274e+20  2.590613e+10  0.820448  train
#
#                     modelo
# 0         Regresión Lineal
# 1         Regresión Lineal
# 0  Arbol de decisión Eli 1
# 1  Arbol de decisión Eli 1
# 0  Arbol de decisión Eli 2
# 1  Arbol de decisión Eli 2
# 0  Arbol de decisión Eli 1
# 1  Arbol de decisión Eli 1
# 0  Arbol de decisión Eli 2
# 1  Arbol de decisión Eli 2
# 0        Random Forest Eli
# 1        Random Forest Eli

# %% [markdown]
# > Los últimos resultados del Random Forest son los que mejor nos han funcionado con diferencia, y aún así, no nos libramos del overfitting, de modo que concluímos que el modelo no se puede realizar con esta aproximación, probablemente por la cantidad de datos disponible.
# >
# > También nos parece interesante comentar que aunque hemos realizado dos encodings diferentes (uno siguiendo el criterio de Eli y otro el de Lidya), ninguno de los dos parece haber dado unos resultados notablemente mejores que el otro, lo que nos hace pensar que el encoding de las variables categóricas no influye significativamente en que las métricas sean tan pobres.

# %%
resultados.to_csv("../datos/esperanza_vida_metricas_eli.csv")
