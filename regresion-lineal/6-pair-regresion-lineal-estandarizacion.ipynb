# %% [markdown]
# # **Ejercicios de pair programming Módulo 3 Sprint 1**
# ## **Regresión lineal: Lección 6**
# ### **Estandarización**
#
# ---

# %% [markdown]
# En vuestro dataset habréis identificado unas variables predictoras y una variable respuesta.

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Para navegar entre directorios
# -----------------------------
import os

# Para realizar la estandarización
# ---------------------------------
from sklearn.preprocessing import StandardScaler

# Para la gestión de los warning
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# Para poder ver todas las columnas del dataframe
# ------------------------------------------------------------------------------
pd.options.display.max_columns = None

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/lidya/Documents/Nuestros documentos/Documentos de Lidya/Estudios/Adalab/modulos/modulo3/pair_programming/promo-d-da-modulo3-sprint1-elisa-lidya/regresion-lineal'

# %%
os.chdir('/mnt/c/Users/lidya/Documents/Nuestros documentos/Documentos de Lidya/Estudios/Adalab/modulos/modulo3/pair_programming/promo-d-da-modulo3-sprint1-elisa-lidya/regresion-lineal')

# %%
df_socio = pd.read_csv('../datos/esperanza_vida_transformado.csv', index_col=0)
df_socio.head(2)
# Out:
#      country        Region  Population in millions (2017)  \
# 0  Argentina  SouthAmerica                         44.271
# 1  Australia       Oceania                         24.451
#
#    Population density (per km2, 2017)  \
# 0                                16.2
# 1                                 3.2
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                      91.749                       14564.5
# 1                                      85.904                       51352.2
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                                   4.8              73.30
# 1                                   9.4              74.25
#
#    Health: Physicians (per 1000 pop.) Quantity of Physicians (per 1000 pop.)  \
# 0                                 3.8                                 Muchos
# 1                                 3.4                                 Medios
#
# ...

# %% [markdown]
# Los objetivos del pair programming de hoy son:
# - Sobre las variables predictoras, en este caso deberéis estandarizar estas variables. De nuevo, usad el método que prefiráis.

# %%
numericas = df_socio.select_dtypes(include = np.number)
numericas.drop('Life expectancy at birth, total (bc-normalized)', axis = 1, inplace = True)

# %%
scaler = StandardScaler()
scaler.fit(numericas)
vp_esc = scaler.transform(numericas)

numericas_estandarizadas = pd.DataFrame(vp_esc, columns = numericas.columns)
numericas_estandarizadas.head(3)
# Out:
#    Population in millions (2017)  Population density (per km2, 2017)  \
# 0                      -0.178879                           -0.273196
# 1                      -0.262734                           -0.283298
# 2                      -0.329221                           -0.203413
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                    1.103154                     -0.439011
# 1                                    0.771296                      1.362030
# 2                                   -0.807657                      1.007846
#
#    Health: Total expenditure (% of GDP)  Health Care Index  \
# 0                             -1.075299           0.742566
# 1                              0.630170           0.837385
# 2                              1.297527           1.502115
#
#    Health: Physicians (per 1000 pop.)  Quality Of Life Index  \
# 0                            0.906869               0.131610
# ...

# %%
df_socio[numericas.columns] = numericas_estandarizadas

# %%
df_socio.head()
# Out:
#      country         Region  Population in millions (2017)  \
# 0  Argentina   SouthAmerica                      -0.178879
# 1  Australia        Oceania                      -0.262734
# 2    Austria  WesternEurope                      -0.329221
# 3    Belarus  EasternEurope                      -0.326124
# 4    Belgium  WesternEurope                      -0.317827
#
#    Population density (per km2, 2017)  \
# 0                           -0.273196
# 1                           -0.283298
# 2                           -0.203413
# 3                           -0.249495
# 4                            0.007568
#
#    Urban population (% of total population)_y  GDP per capita (current US$)  \
# 0                                    1.103154                     -0.439011
# 1                                    0.771296                      1.362030
# 2                                   -0.807657                      1.007846
# ...

# %% [markdown]
# - Guardar en un csv el nuevo dataframe que habéis creado para seguir usándolo en los siguientes pair programmings

# %%
df_socio.to_csv('../datos/esperanza_vida_transformado.csv')
