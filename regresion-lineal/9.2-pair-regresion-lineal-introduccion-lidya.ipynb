# %% [markdown]
# # **Ejercicios de pair programming Módulo 3 Sprint 1**
# ## **Regresión lineal: Lección 9**
# ### **Regresión lineal: Intro**
#
# ---

# %%
# Tratamiento de datos
# --------------------------------
import pandas as pd

# Gráficos
# --------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,8)

# Para evitar que salgan los warnings en jupyter
# --------------------------------
import warnings
warnings.filterwarnings('ignore')

# Modelado y evaluación
# --------------------------------
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#  Crossvalidation
# --------------------------------
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics

pd.options.display.max_columns = None

# %% [markdown]
# En el pair programming de hoy debéis usar el csv que guardastéis cuando hicistéis el pairprgramming de codificicación (este csv debería tener las variables estadandarizas).

# %%
df_socio = pd.read_csv('../datos/datos-regresion-lineal/5.2-esperanza_vida_encoding_lidya.csv', index_col=0)
df_socio.head(2)
# Out:
#            region  population_in_millions  population_density  \
# country
# Argentina       4               -0.178879           -0.273196
# Australia       5               -0.262734           -0.283298
#
#            urban_population_y  gdp_per_capita  health_total_expenditure  \
# country
# Argentina            1.103154       -0.439011                 -1.075299
# Australia            0.771296        1.362030                  0.630170
#
#            health_care_index  quantity_of_physicians  quality_of_life_index  \
# country
# Argentina           0.742566                     3.0               0.131610
# Australia           0.837385                     2.5               1.015861
#
#            purchasing_power_index  safety_index  pollution_index  \
# country
# Argentina               -0.436682     -1.655219         0.057166
# Australia                1.027351     -0.217071        -1.285658
#
#            pop_using_improved_drinking_water  \
# country
# Argentina                           0.474870
# Australia                           0.710275
#
#            life_expectancy_at_birth_total_bc
# country
# Argentina                       1.596496e+11
# Australia                       2.611737e+11

# %% [markdown]
# El objetivo de este pairprogramming es que hagáis vuestro primer modelo de machine learning. Para eso recordad que:
#
#  - Deberéis separar la X y la y.
#  - Deberéis crear el train y el test.
#  - Ajustar vuestro modelo.

# %%
# Separamos x e y
# --------------------------------

y = df_socio['life_expectancy_at_birth_total_bc']
x = df_socio.drop('life_expectancy_at_birth_total_bc', axis=1)

# %%
y.head()
# Out:
# country
# Argentina    1.596496e+11
# Australia    2.611737e+11
# Austria      2.443653e+11
# Belarus      1.320137e+11
# Belgium      2.414933e+11
# Name: life_expectancy_at_birth_total_bc, dtype: float64

# %%
x.head()
# Out:
#            region  population_in_millions  population_density  \
# country
# Argentina       4               -0.178879           -0.273196
# Australia       5               -0.262734           -0.283298
# Austria         5               -0.329221           -0.203413
# Belarus         3               -0.326124           -0.249495
# Belgium         5               -0.317827            0.007568
#
#            urban_population_y  gdp_per_capita  health_total_expenditure  \
# country
# Argentina            1.103154       -0.439011                 -1.075299
# Australia            0.771296        1.362030                  0.630170
# Austria             -0.807657        1.007846                  1.297527
# Belarus              0.330143       -0.870509                 -0.741621
# Belgium              1.455849        0.819853                  1.075075
#
#            health_care_index  quantity_of_physicians  quality_of_life_index  \
# country
# Argentina           0.742566                     3.0               0.131610
# Australia           0.837385                     2.5               1.015861
# Austria             1.502115                     3.0               1.346827
# Belarus            -1.207708                     3.0              -0.355626
# Belgium             1.303495                     2.5               0.632486
#
#            purchasing_power_index  safety_index  pollution_index  \
# country
# Argentina               -0.436682     -1.655219         0.057166
# Australia                1.027351     -0.217071        -1.285658
# Austria                  0.816186      1.431711        -1.410832
# Belarus                 -1.175423      1.217519        -0.582251
# Belgium                  0.660166     -0.365796        -0.148811
#
#            pop_using_improved_drinking_water
# country
# Argentina                           0.474870
# Australia                           0.710275
# Austria                             0.710275
# Belarus                             0.252305
# Belgium                             0.663194

# %%
# Realizamos la regresión lineal
# --------------------------------

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

lr = LinearRegression(n_jobs = -1)

lr.fit(x_train, y_train)

y_predict_train = lr.predict(x_train)
y_predict_test = lr.predict(x_test)

df_train = pd.DataFrame({'real' : y_train, 'predicted' : y_predict_train, 'set' : ['train']* len(y_train)})
df_test = pd.DataFrame({'real' : y_test, 'predicted' : y_predict_test, 'set' : ['test']* len(y_test)})

resultado = pd.concat([df_train, df_test], axis=0)

resultado.head()
# Out:
#                      real     predicted    set
# country
# Brazil       1.478254e+11  1.318990e+11  train
# Israel       2.622094e+11  2.310521e+11  train
# Belgium      2.414933e+11  2.635745e+11  train
# Serbia       1.488658e+11  1.811825e+11  train
# Netherlands  2.466086e+11  2.634239e+11  train

# %%
resultado['residuo'] = resultado['real'] - resultado['predicted']
resultado.head()
# Out:
#                      real     predicted    set       residuo
# country
# Brazil       1.478254e+11  1.318990e+11  train  1.592640e+10
# Israel       2.622094e+11  2.310521e+11  train  3.115733e+10
# Belgium      2.414933e+11  2.635745e+11  train -2.208123e+10
# Serbia       1.488658e+11  1.811825e+11  train -3.231675e+10
# Netherlands  2.466086e+11  2.634239e+11  train -1.681529e+10

# %%
fig, ax = plt.subplots(2,2,figsize=(12,12))

sns.regplot(data = resultado[resultado['set'] == "train"], 
            x = "real", 
            y = "predicted", 
            ax = ax[0,0], 
            color = "purple",
            line_kws = {"color": "orange", "alpha": 0.7 })

sns.regplot(data = resultado[resultado['set'] == "test"], 
            x = "real",
            y = "predicted", 
            color = "purple",
            line_kws = {"color": "orange", "alpha": 0.7 }, 
            ax = ax[1,0])

sns.histplot(resultado[resultado['set'] == "train"],
             x="residuo",
             color ="purple",
             kde=True, 
             ax = ax[0,1])

sns.histplot(resultado[resultado['set'] == "test"],
             x="residuo",
             color = "purple",
             kde=True, 
             ax = ax[1,1])

ax[0,0].set_title("Train reales vs predichos", fontsize = 15, fontweight = "bold")
ax[0,1].set_title("Train residuos", fontsize = 15, fontweight = "bold")
ax[1,0].set_title("Test reales vs predichos", fontsize = 15, fontweight = "bold")
ax[1,1].set_title("Test residuos", fontsize = 15, fontweight = "bold");

# %%
# Sacamos los resultados de la validación cruzada
# --------------------------------

cross = cross_val_score(estimator = LinearRegression(), X = x, y = y, scoring = 'r2', cv = 10)
print(f"Métricas validación cruzada: {cross}") 
print(f"Media métricas de validación cruzada: {cross.mean()}")
# Out:
# Métricas validación cruzada: [ 0.80869206  0.86592213  0.72422523  0.81804101  0.4533424   0.89776948
#   0.32029339  0.86142255  0.82730927 -0.0301202 ]
# Media métricas de validación cruzada: 0.6546897326447335
